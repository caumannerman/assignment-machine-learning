# %% [markdown]
# # Linear Regression

# %% [markdown]
# ## import library

# %%
import numpy as np
import matplotlib.image as img
import matplotlib.pyplot as plt
import matplotlib.colors as colors
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# ## load point data for training and testing

# %%
fname_data  = 'assignment_07_data.csv'

data        = np.genfromtxt(fname_data, delimiter=',')
num_data    = data.shape[0]

xx          = np.zeros(num_data)
yy          = np.zeros(num_data)
zz          = np.zeros(num_data)

for i in range(num_data):

    xx[i] = data[i,0]
    yy[i] = data[i,1]
    zz[i] = data[i,2]
print(xx.shape)
# Out:
# (2500,)

# %% [markdown]
# ## plot the data in the three dimensional space

# %%
fig = plt.figure(figsize=(12, 8))

ax1 = plt.subplot(111, projection='3d')
plt.title('data')

ax1.set_xlabel('$x$')
ax1.set_ylabel('$y$')
ax1.set_zlabel('$z$')

ax1.scatter(xx, yy, zz, marker='o', color='blue', alpha=0.2)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## compute the loss function

# %%
def compute_residual(theta, x, y, z):
    # ===== FILL UP THE CODE =====
    residual = (theta[1]*x + theta[2]*y + theta[0]) - z
    num_data = xx.shape[0]
    residual = residual.reshape(2500,)
    # ============================
    return residual, num_data

# %%
def compute_loss(theta, x, y, z):
    # ===== FILL UP THE CODE =====
    residual, num_data = compute_residual(theta, x, y, z)
    loss = np.sum(residual ** 2) / (num_data*2)
    # ============================
    return loss

# %% [markdown]
# ## compute the gradient for each model parameter (DO NOT COMPUTE THE GRADIENT FOR EACH MODEL PARAMETER, BUT DO COMPUTE THE GRADIENT OF THE MODEL PARAMTER VECTOR)

# %%
def compute_gradient(theta, x, y, z):
    # ===== FILL UP THE CODE =====
    #L(w)를 w에 대하여 미분하면, 1/n ( X.T X w - X.T y ) 
    residual, num_data = compute_residual(theta,x,y,z)
    X = np.ones((2500,3))
    X[:,1] = x
    X[:,2] = y
    grad = (np.matmul(X.T.dot(X),theta.reshape(3,1)) - X.T.dot(z.reshape(z.shape[0],1))) / num_data
    grad = grad.reshape(3,)
    # ============================
    return grad
print(compute_gradient(np.array([0,0,0]), xx,yy,zz))
# Out:
# [  3.01718826  34.234023   -69.41959684]

# %% [markdown]
# ## gradient descent for each model parameter

# %%
num_iteration   = 1000
learning_rate   = 0.01

theta           = np.array((0, 0, 0))
theta_iteration = np.zeros((num_iteration, theta.size))
loss_iteration  = np.zeros(num_iteration)

for i in range(num_iteration):
    # ===== FILL UP THE CODE =====
    theta = theta - compute_gradient(theta,xx,yy,zz)*learning_rate
    theta_iteration[i] = theta
    loss = compute_loss(theta,xx,yy,zz)
    loss_iteration[i] = loss

    # ============================
    print("iteration = %4d, loss = %5.5f," % (i, loss), theta)
# Out:
# iteration =    0, loss = 46.08423, [-0.03017188 -0.34234023  0.69419597]
# iteration =    1, loss = 25.70661, [-0.06000652 -0.562429    1.13990358]
# iteration =    2, loss = 17.25197, [-0.08951998 -0.70392162  1.42606969]
# iteration =    3, loss = 13.71586, [-0.11872364 -0.79488463  1.60980232]
# iteration =    4, loss = 12.20934, [-0.14762584 -0.85336223  1.72776754]
# iteration =    5, loss = 11.54086, [-0.17623297 -0.89095514  1.80350673]
# iteration =    6, loss = 11.21896, [-0.20455013 -0.91512149  1.85213465]
# iteration =    7, loss = 11.04093, [-0.23258163 -0.93065608  1.88335571]
# iteration =    8, loss = 10.92313, [-0.26033121 -0.94064146  1.90340063]
# iteration =    9, loss = 10.83106, [-0.28780226 -0.94705938  1.91626988]
# iteration =   10, loss = 10.75047, [-0.31499793 -0.95118387  1.92453195]
# iteration =   11, loss = 10.67546, [-0.34192123 -0.95383398  1.92983597]
# iteration =   12, loss = 10.60359, [-0.36857502 -0.95553629  1.93324075]
# iteration =   13, loss = 10.53382, [-0.39496209 -0.95662928  1.93542613]
# iteration =   14, loss = 10.46572, [-0.42108518 -0.95733059  1.93682857]
# iteration =   15, loss = 10.39908, [-0.44694697 -0.95778011  1.93772834]
# iteration =   16, loss = 10.33383, [-0.4725501  -0.95806779  1.93830537]
# iteration =   17, loss = 10.26989, [-0.49789716 -0.95825143  1.93867518]
# iteration =   18, loss = 10.20723, [-0.52299074 -0.9583682   1.93891196]
# iteration =   19, loss = 10.14582, [-0.54783336 -0.95844201  1.93906332]
# iteration =   20, loss = 10.08563, [-0.57242756 -0.9584882   1.93915985]
# iteration =   21, loss = 10.02664, [-0.5967758  -0.95851666  1.93922118]
# iteration =   22, loss = 9.96883, [-0.62088056 -0.95853373  1.93925992]
# iteration =   23, loss = 9.91217, [-0.64474427 -0.95854348  1.93928415]
# iteration =   24, loss = 9.85663, [-0.66836934 -0.95854856  1.93929908]
# iteration =   25, loss = 9.80220, [-0.69175816 -0.95855063  1.93930805]
# iteration =   26, loss = 9.74885, [-0.7149131  -0.95855078  1.93931319]
# iteration =   27, loss = 9.69657, [-0.73783648 -0.95854972  1.93931588]
# iteration =   28, loss = 9.64532, [-0.76053063 -0.95854788  1.939317  ]
# iteration =   29, loss = 9.59510, [-0.78299784 -0.95854555  1.93931712]
# iteration =   30, loss = 9.54587, [-0.80524037 -0.95854293  1.93931661]
# iteration =   31, loss = 9.49763, [-0.82726048 -0.95854012  1.93931569]
# iteration =   32, loss = 9.45034, [-0.84906039 -0.95853721  1.93931452]
# iteration =   33, loss = 9.40400, [-0.8706423  -0.95853424  1.9393132 ]
# iteration =   34, loss = 9.35857, [-0.8920084  -0.95853124  1.93931178]
# iteration =   35, loss = 9.31405, [-0.91316083 -0.95852824  1.9393103 ]
# iteration =   36, loss = 9.27042, [-0.93410173 -0.95852525  1.9393088 ]
# iteration =   37, loss = 9.22766, [-0.95483323 -0.95852227  1.93930728]
# iteration =   38, loss = 9.18574, [-0.97535741 -0.95851931  1.93930576]
# iteration =   39, loss = 9.14466, [-0.99567636 -0.95851638  1.93930424]
# iteration =   40, loss = 9.10440, [-1.01579211 -0.95851347  1.93930273]
# iteration =   41, loss = 9.06494, [-1.0357067  -0.95851059  1.93930123]
# iteration =   42, loss = 9.02626, [-1.05542215 -0.95850773  1.93929974]
# iteration =   43, loss = 8.98836, [-1.07494045 -0.9585049   1.93929826]
# iteration =   44, loss = 8.95121, [-1.09426356 -0.9585021   1.9392968 ]
# iteration =   45, loss = 8.91479, [-1.11339344 -0.95849933  1.93929535]
# iteration =   46, loss = 8.87911, [-1.13233202 -0.95849659  1.93929392]
# iteration =   47, loss = 8.84413, [-1.15108122 -0.95849387  1.9392925 ]
# iteration =   48, loss = 8.80985, [-1.16964293 -0.95849118  1.93929109]
# iteration =   49, loss = 8.77625, [-1.18801901 -0.95848851  1.9392897 ]
# iteration =   50, loss = 8.74332, [-1.20621134 -0.95848588  1.93928832]
# iteration =   51, loss = 8.71104, [-1.22422175 -0.95848327  1.93928696]
# iteration =   52, loss = 8.67941, [-1.24205205 -0.95848068  1.93928561]
# iteration =   53, loss = 8.64841, [-1.25970404 -0.95847812  1.93928427]
# iteration =   54, loss = 8.61802, [-1.27717952 -0.95847559  1.93928295]
# iteration =   55, loss = 8.58824, [-1.29448025 -0.95847308  1.93928163]
# iteration =   56, loss = 8.55905, [-1.31160796 -0.9584706   1.93928034]
# iteration =   57, loss = 8.53044, [-1.3285644  -0.95846814  1.93927905]
# iteration =   58, loss = 8.50240, [-1.34535128 -0.95846571  1.93927778]
# iteration =   59, loss = 8.47492, [-1.36197028 -0.9584633   1.93927652]
# iteration =   60, loss = 8.44799, [-1.3784231  -0.95846091  1.93927527]
# iteration =   61, loss = 8.42159, [-1.39471139 -0.95845855  1.93927404]
# iteration =   62, loss = 8.39572, [-1.41083679 -0.95845621  1.93927282]
# iteration =   63, loss = 8.37036, [-1.42680095 -0.9584539   1.93927161]
# iteration =   64, loss = 8.34550, [-1.44260546 -0.95845161  1.93927041]
# iteration =   65, loss = 8.32115, [-1.45825192 -0.95844934  1.93926922]
# iteration =   66, loss = 8.29727, [-1.47374192 -0.95844709  1.93926805]
# iteration =   67, loss = 8.27387, [-1.48907702 -0.95844487  1.93926689]
# iteration =   68, loss = 8.25094, [-1.50425877 -0.95844267  1.93926574]
# iteration =   69, loss = 8.22846, [-1.51928871 -0.95844049  1.9392646 ]
# iteration =   70, loss = 8.20643, [-1.53416834 -0.95843833  1.93926347]
# iteration =   71, loss = 8.18484, [-1.54889918 -0.9584362   1.93926235]
# iteration =   72, loss = 8.16368, [-1.56348271 -0.95843408  1.93926125]
# iteration =   73, loss = 8.14294, [-1.5779204  -0.95843199  1.93926016]
# iteration =   74, loss = 8.12261, [-1.59221372 -0.95842992  1.93925907]
# iteration =   75, loss = 8.10269, [-1.6063641  -0.95842787  1.939258  ]
# iteration =   76, loss = 8.08316, [-1.62037298 -0.95842584  1.93925694]
# iteration =   77, loss = 8.06402, [-1.63424178 -0.95842383  1.93925589]
# iteration =   78, loss = 8.04527, [-1.64797188 -0.95842184  1.93925485]
# iteration =   79, loss = 8.02688, [-1.66156468 -0.95841986  1.93925382]
# iteration =   80, loss = 8.00886, [-1.67502156 -0.95841791  1.9392528 ]
# iteration =   81, loss = 7.99120, [-1.68834386 -0.95841598  1.93925179]
# iteration =   82, loss = 7.97390, [-1.70153295 -0.95841407  1.93925079]
# iteration =   83, loss = 7.95693, [-1.71459014 -0.95841218  1.9392498 ]
# iteration =   84, loss = 7.94031, [-1.72751676 -0.9584103   1.93924882]
# iteration =   85, loss = 7.92401, [-1.74031412 -0.95840845  1.93924785]
# iteration =   86, loss = 7.90804, [-1.7529835  -0.95840661  1.93924689]
# iteration =   87, loss = 7.89239, [-1.76552619 -0.95840479  1.93924594]
# iteration =   88, loss = 7.87704, [-1.77794345 -0.95840299  1.939245  ]
# iteration =   89, loss = 7.86201, [-1.79023654 -0.95840121  1.93924407]
# iteration =   90, loss = 7.84727, [-1.8024067  -0.95839945  1.93924314]
# iteration =   91, loss = 7.83283, [-1.81445515 -0.9583977   1.93924223]
# iteration =   92, loss = 7.81867, [-1.82638312 -0.95839597  1.93924133]
# iteration =   93, loss = 7.80480, [-1.83819182 -0.95839426  1.93924043]
# iteration =   94, loss = 7.79120, [-1.84988242 -0.95839256  1.93923955]
# iteration =   95, loss = 7.77787, [-1.86145612 -0.95839089  1.93923867]
# iteration =   96, loss = 7.76481, [-1.87291408 -0.95838923  1.9392378 ]
# iteration =   97, loss = 7.75200, [-1.88425747 -0.95838758  1.93923694]
# iteration =   98, loss = 7.73945, [-1.89548742 -0.95838595  1.93923609]
# iteration =   99, loss = 7.72716, [-1.90660507 -0.95838434  1.93923525]
# iteration =  100, loss = 7.71510, [-1.91761154 -0.95838275  1.93923441]
# iteration =  101, loss = 7.70329, [-1.92850795 -0.95838117  1.93923359]
# iteration =  102, loss = 7.69171, [-1.9392954  -0.9583796   1.93923277]
# iteration =  103, loss = 7.68036, [-1.94997497 -0.95837805  1.93923196]
# iteration =  104, loss = 7.66924, [-1.96054774 -0.95837652  1.93923116]
# iteration =  105, loss = 7.65834, [-1.97101479 -0.958375    1.93923037]
# iteration =  106, loss = 7.64765, [-1.98137717 -0.9583735   1.93922958]
# iteration =  107, loss = 7.63718, [-1.99163592 -0.95837201  1.9392288 ]
# iteration =  108, loss = 7.62692, [-2.00179209 -0.95837054  1.93922804]
# iteration =  109, loss = 7.61686, [-2.01184669 -0.95836908  1.93922727]
# iteration =  110, loss = 7.60700, [-2.02180075 -0.95836764  1.93922652]
# iteration =  111, loss = 7.59734, [-2.03165527 -0.95836621  1.93922577]
# iteration =  112, loss = 7.58787, [-2.04141124 -0.9583648   1.93922503]
# iteration =  113, loss = 7.57859, [-2.05106965 -0.9583634   1.9392243 ]
# iteration =  114, loss = 7.56949, [-2.06063148 -0.95836201  1.93922358]
# iteration =  115, loss = 7.56057, [-2.07009769 -0.95836064  1.93922286]
# iteration =  116, loss = 7.55184, [-2.07946924 -0.95835928  1.93922215]
# iteration =  117, loss = 7.54327, [-2.08874708 -0.95835794  1.93922145]
# iteration =  118, loss = 7.53488, [-2.09793213 -0.9583566   1.93922075]
# iteration =  119, loss = 7.52665, [-2.10702534 -0.95835529  1.93922006]
# iteration =  120, loss = 7.51859, [-2.11602761 -0.95835398  1.93921938]
# iteration =  121, loss = 7.51068, [-2.12493986 -0.95835269  1.9392187 ]
# iteration =  122, loss = 7.50294, [-2.13376299 -0.95835141  1.93921803]
# iteration =  123, loss = 7.49534, [-2.14249788 -0.95835014  1.93921737]
# iteration =  124, loss = 7.48790, [-2.15114543 -0.95834889  1.93921672]
# iteration =  125, loss = 7.48061, [-2.1597065  -0.95834765  1.93921607]
# iteration =  126, loss = 7.47346, [-2.16818197 -0.95834642  1.93921543]
# iteration =  127, loss = 7.46646, [-2.17657267 -0.9583452   1.93921479]
# iteration =  128, loss = 7.45959, [-2.18487947 -0.958344    1.93921416]
# iteration =  129, loss = 7.45286, [-2.19310321 -0.95834281  1.93921354]
# iteration =  130, loss = 7.44627, [-2.2012447  -0.95834163  1.93921292]
# iteration =  131, loss = 7.43980, [-2.20930478 -0.95834046  1.93921231]
# iteration =  132, loss = 7.43347, [-2.21728426 -0.9583393   1.93921171]
# iteration =  133, loss = 7.42726, [-2.22518394 -0.95833816  1.93921111]
# iteration =  134, loss = 7.42117, [-2.23300463 -0.95833702  1.93921051]
# iteration =  135, loss = 7.41521, [-2.24074711 -0.9583359   1.93920993]
# iteration =  136, loss = 7.40936, [-2.24841217 -0.95833479  1.93920935]
# iteration =  137, loss = 7.40363, [-2.25600058 -0.95833369  1.93920877]
# iteration =  138, loss = 7.39802, [-2.2635131 -0.9583326  1.9392082]
# iteration =  139, loss = 7.39251, [-2.27095049 -0.95833152  1.93920764]
# iteration =  140, loss = 7.38712, [-2.27831352 -0.95833045  1.93920708]
# iteration =  141, loss = 7.38183, [-2.28560291 -0.9583294   1.93920653]
# iteration =  142, loss = 7.37665, [-2.29281941 -0.95832835  1.93920598]
# iteration =  143, loss = 7.37157, [-2.29996374 -0.95832732  1.93920544]
# iteration =  144, loss = 7.36660, [-2.30703663 -0.95832629  1.9392049 ]
# iteration =  145, loss = 7.36172, [-2.3140388  -0.95832528  1.93920437]
# iteration =  146, loss = 7.35694, [-2.32097094 -0.95832427  1.93920385]
# iteration =  147, loss = 7.35225, [-2.32783375 -0.95832328  1.93920333]
# iteration =  148, loss = 7.34766, [-2.33462795 -0.95832229  1.93920281]
# iteration =  149, loss = 7.34315, [-2.34135419 -0.95832132  1.9392023 ]
# iteration =  150, loss = 7.33874, [-2.34801318 -0.95832035  1.9392018 ]
# iteration =  151, loss = 7.33442, [-2.35460558 -0.95831939  1.9392013 ]
# iteration =  152, loss = 7.33018, [-2.36113205 -0.95831845  1.9392008 ]
# iteration =  153, loss = 7.32603, [-2.36759326 -0.95831751  1.93920031]
# iteration =  154, loss = 7.32195, [-2.37398985 -0.95831658  1.93919983]
# iteration =  155, loss = 7.31796, [-2.38032248 -0.95831567  1.93919935]
# iteration =  156, loss = 7.31405, [-2.38659179 -0.95831476  1.93919888]
# iteration =  157, loss = 7.31022, [-2.3927984  -0.95831386  1.9391984 ]
# iteration =  158, loss = 7.30646, [-2.39894294 -0.95831297  1.93919794]
# iteration =  159, loss = 7.30278, [-2.40502604 -0.95831209  1.93919748]
# iteration =  160, loss = 7.29917, [-2.41104831 -0.95831121  1.93919702]
# iteration =  161, loss = 7.29564, [-2.41701036 -0.95831035  1.93919657]
# iteration =  162, loss = 7.29217, [-2.42291278 -0.95830949  1.93919612]
# iteration =  163, loss = 7.28877, [-2.42875619 -0.95830865  1.93919568]
# iteration =  164, loss = 7.28544, [-2.43454115 -0.95830781  1.93919524]
# iteration =  165, loss = 7.28218, [-2.44026827 -0.95830698  1.93919481]
# iteration =  166, loss = 7.27898, [-2.44593812 -0.95830615  1.93919438]
# iteration =  167, loss = 7.27585, [-2.45155127 -0.95830534  1.93919395]
# iteration =  168, loss = 7.27277, [-2.45710828 -0.95830453  1.93919353]
# iteration =  169, loss = 7.26976, [-2.46260973 -0.95830374  1.93919311]
# iteration =  170, loss = 7.26681, [-2.46805616 -0.95830295  1.9391927 ]
# iteration =  171, loss = 7.26392, [-2.47344813 -0.95830217  1.93919229]
# iteration =  172, loss = 7.26108, [-2.47878618 -0.95830139  1.93919189]
# iteration =  173, loss = 7.25830, [-2.48407085 -0.95830063  1.93919149]
# iteration =  174, loss = 7.25558, [-2.48930267 -0.95829987  1.93919109]
# iteration =  175, loss = 7.25291, [-2.49448217 -0.95829912  1.9391907 ]
# iteration =  176, loss = 7.25029, [-2.49960988 -0.95829837  1.93919031]
# iteration =  177, loss = 7.24773, [-2.50468631 -0.95829764  1.93918993]
# iteration =  178, loss = 7.24522, [-2.50971198 -0.95829691  1.93918955]
# iteration =  179, loss = 7.24275, [-2.51468739 -0.95829619  1.93918917]
# iteration =  180, loss = 7.24034, [-2.51961304 -0.95829547  1.93918879]
# iteration =  181, loss = 7.23797, [-2.52448944 -0.95829477  1.93918843]
# iteration =  182, loss = 7.23566, [-2.52931708 -0.95829407  1.93918806]
# iteration =  183, loss = 7.23338, [-2.53409644 -0.95829337  1.9391877 ]
# iteration =  184, loss = 7.23115, [-2.538828   -0.95829269  1.93918734]
# iteration =  185, loss = 7.22897, [-2.54351225 -0.95829201  1.93918698]
# iteration =  186, loss = 7.22683, [-2.54814966 -0.95829134  1.93918663]
# iteration =  187, loss = 7.22473, [-2.5527407  -0.95829067  1.93918628]
# iteration =  188, loss = 7.22268, [-2.55728582 -0.95829001  1.93918594]
# iteration =  189, loss = 7.22066, [-2.56178549 -0.95828936  1.9391856 ]
# iteration =  190, loss = 7.21869, [-2.56624017 -0.95828871  1.93918526]
# iteration =  191, loss = 7.21675, [-2.5706503  -0.95828807  1.93918493]
# iteration =  192, loss = 7.21486, [-2.57501632 -0.95828744  1.9391846 ]
# iteration =  193, loss = 7.21300, [-2.57933869 -0.95828682  1.93918427]
# iteration =  194, loss = 7.21118, [-2.58361784 -0.95828619  1.93918394]
# iteration =  195, loss = 7.20939, [-2.58785419 -0.95828558  1.93918362]
# iteration =  196, loss = 7.20764, [-2.59204818 -0.95828497  1.93918331]
# iteration =  197, loss = 7.20593, [-2.59620023 -0.95828437  1.93918299]
# iteration =  198, loss = 7.20424, [-2.60031075 -0.95828377  1.93918268]
# iteration =  199, loss = 7.20260, [-2.60438018 -0.95828319  1.93918237]
# iteration =  200, loss = 7.20098, [-2.60840891 -0.9582826   1.93918207]
# iteration =  201, loss = 7.19940, [-2.61239735 -0.95828202  1.93918176]
# iteration =  202, loss = 7.19785, [-2.61634591 -0.95828145  1.93918146]
# iteration =  203, loss = 7.19633, [-2.62025498 -0.95828088  1.93918117]
# iteration =  204, loss = 7.19484, [-2.62412496 -0.95828032  1.93918088]
# iteration =  205, loss = 7.19338, [-2.62795624 -0.95827977  1.93918058]
# iteration =  206, loss = 7.19195, [-2.63174921 -0.95827922  1.9391803 ]
# iteration =  207, loss = 7.19054, [-2.63550425 -0.95827867  1.93918001]
# iteration =  208, loss = 7.18917, [-2.63922174 -0.95827813  1.93917973]
# iteration =  209, loss = 7.18782, [-2.64290205 -0.9582776   1.93917945]
# iteration =  210, loss = 7.18650, [-2.64654556 -0.95827707  1.93917918]
# iteration =  211, loss = 7.18520, [-2.65015264 -0.95827655  1.9391789 ]
# iteration =  212, loss = 7.18394, [-2.65372364 -0.95827603  1.93917863]
# iteration =  213, loss = 7.18269, [-2.65725894 -0.95827552  1.93917836]
# iteration =  214, loss = 7.18147, [-2.66075888 -0.95827501  1.9391781 ]
# iteration =  215, loss = 7.18028, [-2.66422382 -0.95827451  1.93917784]
# iteration =  216, loss = 7.17911, [-2.66765412 -0.95827401  1.93917758]
# iteration =  217, loss = 7.17796, [-2.67105011 -0.95827352  1.93917732]
# iteration =  218, loss = 7.17684, [-2.67441214 -0.95827303  1.93917706]
# iteration =  219, loss = 7.17573, [-2.67774055 -0.95827255  1.93917681]
# iteration =  220, loss = 7.17465, [-2.68103567 -0.95827207  1.93917656]
# iteration =  221, loss = 7.17359, [-2.68429785 -0.9582716   1.93917632]
# iteration =  222, loss = 7.17256, [-2.6875274  -0.95827113  1.93917607]
# iteration =  223, loss = 7.17154, [-2.69072466 -0.95827067  1.93917583]
# iteration =  224, loss = 7.17054, [-2.69388994 -0.95827021  1.93917559]
# iteration =  225, loss = 7.16956, [-2.69702358 -0.95826975  1.93917535]
# iteration =  226, loss = 7.16861, [-2.70012587 -0.9582693   1.93917512]
# iteration =  227, loss = 7.16767, [-2.70319715 -0.95826886  1.93917488]
# iteration =  228, loss = 7.16675, [-2.70623771 -0.95826842  1.93917465]
# iteration =  229, loss = 7.16585, [-2.70924786 -0.95826798  1.93917442]
# iteration =  230, loss = 7.16496, [-2.71222791 -0.95826755  1.9391742 ]
# iteration =  231, loss = 7.16410, [-2.71517817 -0.95826712  1.93917398]
# iteration =  232, loss = 7.16325, [-2.71809892 -0.9582667   1.93917375]
# iteration =  233, loss = 7.16242, [-2.72099046 -0.95826628  1.93917353]
# iteration =  234, loss = 7.16160, [-2.72385309 -0.95826587  1.93917332]
# iteration =  235, loss = 7.16080, [-2.72668709 -0.95826545  1.9391731 ]
# iteration =  236, loss = 7.16002, [-2.72949275 -0.95826505  1.93917289]
# iteration =  237, loss = 7.15925, [-2.73227035 -0.95826464  1.93917268]
# iteration =  238, loss = 7.15850, [-2.73502018 -0.95826425  1.93917247]
# iteration =  239, loss = 7.15776, [-2.73774251 -0.95826385  1.93917227]
# iteration =  240, loss = 7.15704, [-2.74043762 -0.95826346  1.93917206]
# iteration =  241, loss = 7.15633, [-2.74310578 -0.95826307  1.93917186]
# iteration =  242, loss = 7.15564, [-2.74574725 -0.95826269  1.93917166]
# iteration =  243, loss = 7.15496, [-2.74836231 -0.95826231  1.93917146]
# iteration =  244, loss = 7.15429, [-2.75095122 -0.95826194  1.93917126]
# iteration =  245, loss = 7.15364, [-2.75351424 -0.95826157  1.93917107]
# iteration =  246, loss = 7.15299, [-2.75605163 -0.9582612   1.93917088]
# iteration =  247, loss = 7.15237, [-2.75856365 -0.95826083  1.93917069]
# iteration =  248, loss = 7.15175, [-2.76105054 -0.95826047  1.9391705 ]
# iteration =  249, loss = 7.15115, [-2.76351257 -0.95826012  1.93917031]
# iteration =  250, loss = 7.15056, [-2.76594997 -0.95825976  1.93917013]
# iteration =  251, loss = 7.14998, [-2.76836301 -0.95825941  1.93916994]
# iteration =  252, loss = 7.14941, [-2.77075191 -0.95825907  1.93916976]
# iteration =  253, loss = 7.14885, [-2.77311692 -0.95825872  1.93916958]
# iteration =  254, loss = 7.14831, [-2.77545829 -0.95825838  1.93916941]
# iteration =  255, loss = 7.14777, [-2.77777624 -0.95825805  1.93916923]
# iteration =  256, loss = 7.14725, [-2.78007101 -0.95825772  1.93916906]
# iteration =  257, loss = 7.14674, [-2.78234283 -0.95825739  1.93916889]
# iteration =  258, loss = 7.14623, [-2.78459193 -0.95825706  1.93916872]
# iteration =  259, loss = 7.14574, [-2.78681855 -0.95825674  1.93916855]
# iteration =  260, loss = 7.14526, [-2.78902289 -0.95825642  1.93916838]
# iteration =  261, loss = 7.14478, [-2.7912052  -0.9582561   1.93916821]
# iteration =  262, loss = 7.14432, [-2.79336568 -0.95825579  1.93916805]
# iteration =  263, loss = 7.14386, [-2.79550455 -0.95825548  1.93916789]
# iteration =  264, loss = 7.14342, [-2.79762204 -0.95825517  1.93916773]
# iteration =  265, loss = 7.14298, [-2.79971835 -0.95825487  1.93916757]
# iteration =  266, loss = 7.14255, [-2.8017937  -0.95825457  1.93916741]
# iteration =  267, loss = 7.14213, [-2.8038483  -0.95825427  1.93916726]
# iteration =  268, loss = 7.14172, [-2.80588235 -0.95825397  1.9391671 ]
# iteration =  269, loss = 7.14132, [-2.80789606 -0.95825368  1.93916695]
# iteration =  270, loss = 7.14092, [-2.80988963 -0.95825339  1.9391668 ]
# iteration =  271, loss = 7.14053, [-2.81186327 -0.95825311  1.93916665]
# iteration =  272, loss = 7.14015, [-2.81381717 -0.95825282  1.9391665 ]
# iteration =  273, loss = 7.13978, [-2.81575153 -0.95825254  1.93916635]
# iteration =  274, loss = 7.13942, [-2.81766655 -0.95825226  1.93916621]
# iteration =  275, loss = 7.13906, [-2.81956241 -0.95825199  1.93916606]
# iteration =  276, loss = 7.13871, [-2.82143932 -0.95825172  1.93916592]
# iteration =  277, loss = 7.13836, [-2.82329746 -0.95825145  1.93916578]
# iteration =  278, loss = 7.13803, [-2.82513702 -0.95825118  1.93916564]
# iteration =  279, loss = 7.13770, [-2.82695818 -0.95825092  1.9391655 ]
# iteration =  280, loss = 7.13737, [-2.82876113 -0.95825066  1.93916537]
# iteration =  281, loss = 7.13706, [-2.83054606 -0.9582504   1.93916523]
# iteration =  282, loss = 7.13675, [-2.83231313 -0.95825014  1.9391651 ]
# iteration =  283, loss = 7.13644, [-2.83406253 -0.95824989  1.93916497]
# iteration =  284, loss = 7.13614, [-2.83579444 -0.95824964  1.93916483]
# iteration =  285, loss = 7.13585, [-2.83750903 -0.95824939  1.93916471]
# iteration =  286, loss = 7.13556, [-2.83920647 -0.95824914  1.93916458]
# iteration =  287, loss = 7.13528, [-2.84088694 -0.9582489   1.93916445]
# iteration =  288, loss = 7.13501, [-2.8425506  -0.95824866  1.93916432]
# iteration =  289, loss = 7.13474, [-2.84419763 -0.95824842  1.9391642 ]
# iteration =  290, loss = 7.13447, [-2.84582819 -0.95824818  1.93916407]
# iteration =  291, loss = 7.13421, [-2.84744244 -0.95824795  1.93916395]
# iteration =  292, loss = 7.13396, [-2.84904055 -0.95824772  1.93916383]
# iteration =  293, loss = 7.13371, [-2.85062267 -0.95824749  1.93916371]
# iteration =  294, loss = 7.13347, [-2.85218898 -0.95824726  1.93916359]
# iteration =  295, loss = 7.13323, [-2.85373962 -0.95824704  1.93916348]
# iteration =  296, loss = 7.13299, [-2.85527476 -0.95824681  1.93916336]
# iteration =  297, loss = 7.13276, [-2.85679455 -0.95824659  1.93916324]
# iteration =  298, loss = 7.13254, [-2.85829913 -0.95824637  1.93916313]
# iteration =  299, loss = 7.13232, [-2.85978868 -0.95824616  1.93916302]
# iteration =  300, loss = 7.13210, [-2.86126332 -0.95824594  1.9391629 ]
# iteration =  301, loss = 7.13189, [-2.86272322 -0.95824573  1.93916279]
# iteration =  302, loss = 7.13168, [-2.86416852 -0.95824552  1.93916268]
# iteration =  303, loss = 7.13148, [-2.86559937 -0.95824532  1.93916258]
# iteration =  304, loss = 7.13128, [-2.86701591 -0.95824511  1.93916247]
# iteration =  305, loss = 7.13108, [-2.86841829 -0.95824491  1.93916236]
# iteration =  306, loss = 7.13089, [-2.86980664 -0.95824471  1.93916226]
# iteration =  307, loss = 7.13070, [-2.8711811  -0.95824451  1.93916215]
# iteration =  308, loss = 7.13052, [-2.87254183 -0.95824431  1.93916205]
# iteration =  309, loss = 7.13034, [-2.87388894 -0.95824411  1.93916195]
# iteration =  310, loss = 7.13016, [-2.87522258 -0.95824392  1.93916185]
# iteration =  311, loss = 7.12999, [-2.87654289 -0.95824373  1.93916175]
# iteration =  312, loss = 7.12982, [-2.87785    -0.95824354  1.93916165]
# iteration =  313, loss = 7.12965, [-2.87914403 -0.95824335  1.93916155]
# iteration =  314, loss = 7.12949, [-2.88042512 -0.95824317  1.93916145]
# iteration =  315, loss = 7.12933, [-2.88169341 -0.95824298  1.93916136]
# iteration =  316, loss = 7.12917, [-2.882949   -0.9582428   1.93916126]
# iteration =  317, loss = 7.12902, [-2.88419205 -0.95824262  1.93916117]
# iteration =  318, loss = 7.12887, [-2.88542266 -0.95824244  1.93916107]
# iteration =  319, loss = 7.12872, [-2.88664097 -0.95824227  1.93916098]
# iteration =  320, loss = 7.12857, [-2.88784709 -0.95824209  1.93916089]
# iteration =  321, loss = 7.12843, [-2.88904115 -0.95824192  1.9391608 ]
# iteration =  322, loss = 7.12829, [-2.89022328 -0.95824175  1.93916071]
# iteration =  323, loss = 7.12816, [-2.89139358 -0.95824158  1.93916062]
# iteration =  324, loss = 7.12802, [-2.89255218 -0.95824141  1.93916053]
# iteration =  325, loss = 7.12789, [-2.89369919 -0.95824124  1.93916045]
# iteration =  326, loss = 7.12776, [-2.89483473 -0.95824108  1.93916036]
# iteration =  327, loss = 7.12764, [-2.89595892 -0.95824091  1.93916028]
# iteration =  328, loss = 7.12751, [-2.89707186 -0.95824075  1.93916019]
# iteration =  329, loss = 7.12739, [-2.89817367 -0.95824059  1.93916011]
# iteration =  330, loss = 7.12727, [-2.89926447 -0.95824044  1.93916003]
# iteration =  331, loss = 7.12716, [-2.90034436 -0.95824028  1.93915994]
# iteration =  332, loss = 7.12704, [-2.90141345 -0.95824012  1.93915986]
# iteration =  333, loss = 7.12693, [-2.90247185 -0.95823997  1.93915978]
# iteration =  334, loss = 7.12682, [-2.90351967 -0.95823982  1.9391597 ]
# iteration =  335, loss = 7.12672, [-2.904557   -0.95823967  1.93915962]
# iteration =  336, loss = 7.12661, [-2.90558397 -0.95823952  1.93915955]
# iteration =  337, loss = 7.12651, [-2.90660066 -0.95823937  1.93915947]
# iteration =  338, loss = 7.12641, [-2.90760719 -0.95823923  1.93915939]
# iteration =  339, loss = 7.12631, [-2.90860365 -0.95823908  1.93915932]
# iteration =  340, loss = 7.12621, [-2.90959015 -0.95823894  1.93915924]
# iteration =  341, loss = 7.12612, [-2.91056678 -0.9582388   1.93915917]
# iteration =  342, loss = 7.12602, [-2.91153364 -0.95823866  1.9391591 ]
# iteration =  343, loss = 7.12593, [-2.91249084 -0.95823852  1.93915902]
# iteration =  344, loss = 7.12584, [-2.91343847 -0.95823838  1.93915895]
# iteration =  345, loss = 7.12576, [-2.91437662 -0.95823824  1.93915888]
# iteration =  346, loss = 7.12567, [-2.91530538 -0.95823811  1.93915881]
# iteration =  347, loss = 7.12559, [-2.91622486 -0.95823798  1.93915874]
# iteration =  348, loss = 7.12550, [-2.91713515 -0.95823785  1.93915867]
# iteration =  349, loss = 7.12542, [-2.91803633 -0.95823771  1.9391586 ]
# iteration =  350, loss = 7.12534, [-2.9189285  -0.95823759  1.93915854]
# iteration =  351, loss = 7.12527, [-2.91981175 -0.95823746  1.93915847]
# iteration =  352, loss = 7.12519, [-2.92068617 -0.95823733  1.9391584 ]
# iteration =  353, loss = 7.12512, [-2.92155184 -0.9582372   1.93915834]
# iteration =  354, loss = 7.12504, [-2.92240886 -0.95823708  1.93915827]
# iteration =  355, loss = 7.12497, [-2.9232573  -0.95823696  1.93915821]
# iteration =  356, loss = 7.12490, [-2.92409726 -0.95823684  1.93915814]
# iteration =  357, loss = 7.12483, [-2.92492882 -0.95823672  1.93915808]
# iteration =  358, loss = 7.12476, [-2.92575207 -0.9582366   1.93915802]
# iteration =  359, loss = 7.12470, [-2.92656708 -0.95823648  1.93915796]
# iteration =  360, loss = 7.12463, [-2.92737394 -0.95823636  1.9391579 ]
# iteration =  361, loss = 7.12457, [-2.92817274 -0.95823624  1.93915783]
# iteration =  362, loss = 7.12451, [-2.92896355 -0.95823613  1.93915777]
# iteration =  363, loss = 7.12445, [-2.92974644 -0.95823602  1.93915772]
# iteration =  364, loss = 7.12439, [-2.93052151 -0.9582359   1.93915766]
# iteration =  365, loss = 7.12433, [-2.93128883 -0.95823579  1.9391576 ]
# iteration =  366, loss = 7.12427, [-2.93204848 -0.95823568  1.93915754]
# iteration =  367, loss = 7.12422, [-2.93280053 -0.95823557  1.93915748]
# iteration =  368, loss = 7.12416, [-2.93354506 -0.95823547  1.93915743]
# iteration =  369, loss = 7.12411, [-2.93428214 -0.95823536  1.93915737]
# iteration =  370, loss = 7.12405, [-2.93501185 -0.95823525  1.93915732]
# iteration =  371, loss = 7.12400, [-2.93573427 -0.95823515  1.93915726]
# iteration =  372, loss = 7.12395, [-2.93644946 -0.95823505  1.93915721]
# iteration =  373, loss = 7.12390, [-2.9371575  -0.95823494  1.93915715]
# iteration =  374, loss = 7.12385, [-2.93785846 -0.95823484  1.9391571 ]
# iteration =  375, loss = 7.12380, [-2.93855241 -0.95823474  1.93915705]
# iteration =  376, loss = 7.12376, [-2.93923942 -0.95823464  1.939157  ]
# iteration =  377, loss = 7.12371, [-2.93991956 -0.95823454  1.93915694]
# iteration =  378, loss = 7.12367, [-2.9405929  -0.95823444  1.93915689]
# iteration =  379, loss = 7.12362, [-2.9412595  -0.95823435  1.93915684]
# iteration =  380, loss = 7.12358, [-2.94191944 -0.95823425  1.93915679]
# iteration =  381, loss = 7.12354, [-2.94257278 -0.95823416  1.93915674]
# iteration =  382, loss = 7.12349, [-2.94321959 -0.95823406  1.93915669]
# iteration =  383, loss = 7.12345, [-2.94385992 -0.95823397  1.93915665]
# iteration =  384, loss = 7.12341, [-2.94449386 -0.95823388  1.9391566 ]
# iteration =  385, loss = 7.12337, [-2.94512145 -0.95823379  1.93915655]
# iteration =  386, loss = 7.12334, [-2.94574277 -0.9582337   1.9391565 ]
# iteration =  387, loss = 7.12330, [-2.94635788 -0.95823361  1.93915646]
# iteration =  388, loss = 7.12326, [-2.94696684 -0.95823352  1.93915641]
# iteration =  389, loss = 7.12322, [-2.9475697  -0.95823343  1.93915636]
# iteration =  390, loss = 7.12319, [-2.94816654 -0.95823335  1.93915632]
# iteration =  391, loss = 7.12315, [-2.94875741 -0.95823326  1.93915627]
# iteration =  392, loss = 7.12312, [-2.94934237 -0.95823318  1.93915623]
# iteration =  393, loss = 7.12309, [-2.94992148 -0.95823309  1.93915619]
# iteration =  394, loss = 7.12305, [-2.9504948  -0.95823301  1.93915614]
# iteration =  395, loss = 7.12302, [-2.95106238 -0.95823293  1.9391561 ]
# iteration =  396, loss = 7.12299, [-2.95162429 -0.95823285  1.93915606]
# iteration =  397, loss = 7.12296, [-2.95218058 -0.95823276  1.93915602]
# iteration =  398, loss = 7.12293, [-2.95273131 -0.95823268  1.93915597]
# iteration =  399, loss = 7.12290, [-2.95327653 -0.95823261  1.93915593]
# iteration =  400, loss = 7.12287, [-2.9538163  -0.95823253  1.93915589]
# iteration =  401, loss = 7.12284, [-2.95435067 -0.95823245  1.93915585]
# iteration =  402, loss = 7.12282, [-2.9548797  -0.95823237  1.93915581]
# iteration =  403, loss = 7.12279, [-2.95540344 -0.9582323   1.93915577]
# iteration =  404, loss = 7.12276, [-2.95592194 -0.95823222  1.93915573]
# iteration =  405, loss = 7.12273, [-2.95643525 -0.95823215  1.93915569]
# iteration =  406, loss = 7.12271, [-2.95694343 -0.95823207  1.93915565]
# iteration =  407, loss = 7.12268, [-2.95744653 -0.958232    1.93915562]
# iteration =  408, loss = 7.12266, [-2.9579446  -0.95823193  1.93915558]
# iteration =  409, loss = 7.12264, [-2.95843769 -0.95823186  1.93915554]
# iteration =  410, loss = 7.12261, [-2.95892585 -0.95823179  1.9391555 ]
# iteration =  411, loss = 7.12259, [-2.95940912 -0.95823172  1.93915547]
# iteration =  412, loss = 7.12257, [-2.95988757 -0.95823165  1.93915543]
# iteration =  413, loss = 7.12254, [-2.96036123 -0.95823158  1.9391554 ]
# iteration =  414, loss = 7.12252, [-2.96083015 -0.95823151  1.93915536]
# iteration =  415, loss = 7.12250, [-2.96129438 -0.95823144  1.93915532]
# iteration =  416, loss = 7.12248, [-2.96175397 -0.95823138  1.93915529]
# iteration =  417, loss = 7.12246, [-2.96220897 -0.95823131  1.93915526]
# iteration =  418, loss = 7.12244, [-2.96265941 -0.95823125  1.93915522]
# iteration =  419, loss = 7.12242, [-2.96310535 -0.95823118  1.93915519]
# iteration =  420, loss = 7.12240, [-2.96354683 -0.95823112  1.93915515]
# iteration =  421, loss = 7.12238, [-2.9639839  -0.95823105  1.93915512]
# iteration =  422, loss = 7.12236, [-2.96441659 -0.95823099  1.93915509]
# iteration =  423, loss = 7.12234, [-2.96484496 -0.95823093  1.93915506]
# iteration =  424, loss = 7.12232, [-2.96526905 -0.95823087  1.93915502]
# iteration =  425, loss = 7.12231, [-2.96568889 -0.95823081  1.93915499]
# iteration =  426, loss = 7.12229, [-2.96610453 -0.95823075  1.93915496]
# iteration =  427, loss = 7.12227, [-2.96651602 -0.95823069  1.93915493]
# iteration =  428, loss = 7.12226, [-2.9669234  -0.95823063  1.9391549 ]
# iteration =  429, loss = 7.12224, [-2.9673267  -0.95823057  1.93915487]
# iteration =  430, loss = 7.12222, [-2.96772597 -0.95823051  1.93915484]
# iteration =  431, loss = 7.12221, [-2.96812124 -0.95823045  1.93915481]
# iteration =  432, loss = 7.12219, [-2.96851256 -0.9582304   1.93915478]
# iteration =  433, loss = 7.12218, [-2.96889997 -0.95823034  1.93915475]
# iteration =  434, loss = 7.12216, [-2.96928351 -0.95823029  1.93915472]
# iteration =  435, loss = 7.12215, [-2.9696632  -0.95823023  1.93915469]
# iteration =  436, loss = 7.12214, [-2.97003911 -0.95823018  1.93915466]
# iteration =  437, loss = 7.12212, [-2.97041125 -0.95823012  1.93915463]
# iteration =  438, loss = 7.12211, [-2.97077967 -0.95823007  1.93915461]
# iteration =  439, loss = 7.12210, [-2.97114441 -0.95823002  1.93915458]
# iteration =  440, loss = 7.12208, [-2.9715055  -0.95822996  1.93915455]
# iteration =  441, loss = 7.12207, [-2.97186298 -0.95822991  1.93915452]
# iteration =  442, loss = 7.12206, [-2.97221688 -0.95822986  1.9391545 ]
# iteration =  443, loss = 7.12205, [-2.97256725 -0.95822981  1.93915447]
# iteration =  444, loss = 7.12203, [-2.97291411 -0.95822976  1.93915444]
# iteration =  445, loss = 7.12202, [-2.9732575  -0.95822971  1.93915442]
# iteration =  446, loss = 7.12201, [-2.97359746 -0.95822966  1.93915439]
# iteration =  447, loss = 7.12200, [-2.97393402 -0.95822961  1.93915437]
# iteration =  448, loss = 7.12199, [-2.97426722 -0.95822956  1.93915434]
# iteration =  449, loss = 7.12198, [-2.97459708 -0.95822951  1.93915432]
# iteration =  450, loss = 7.12197, [-2.97492364 -0.95822947  1.93915429]
# iteration =  451, loss = 7.12196, [-2.97524694 -0.95822942  1.93915427]
# iteration =  452, loss = 7.12195, [-2.97556701 -0.95822937  1.93915424]
# iteration =  453, loss = 7.12194, [-2.97588387 -0.95822933  1.93915422]
# iteration =  454, loss = 7.12193, [-2.97619757 -0.95822928  1.9391542 ]
# iteration =  455, loss = 7.12192, [-2.97650813 -0.95822924  1.93915417]
# iteration =  456, loss = 7.12191, [-2.97681558 -0.95822919  1.93915415]
# iteration =  457, loss = 7.12190, [-2.97711996 -0.95822915  1.93915413]
# iteration =  458, loss = 7.12189, [-2.97742129 -0.95822911  1.9391541 ]
# iteration =  459, loss = 7.12188, [-2.97771961 -0.95822906  1.93915408]
# iteration =  460, loss = 7.12187, [-2.97801495 -0.95822902  1.93915406]
# iteration =  461, loss = 7.12186, [-2.97830734 -0.95822898  1.93915404]
# iteration =  462, loss = 7.12185, [-2.9785968  -0.95822893  1.93915401]
# iteration =  463, loss = 7.12185, [-2.97888336 -0.95822889  1.93915399]
# iteration =  464, loss = 7.12184, [-2.97916706 -0.95822885  1.93915397]
# iteration =  465, loss = 7.12183, [-2.97944793 -0.95822881  1.93915395]
# iteration =  466, loss = 7.12182, [-2.97972598 -0.95822877  1.93915393]
# iteration =  467, loss = 7.12181, [-2.98000126 -0.95822873  1.93915391]
# iteration =  468, loss = 7.12181, [-2.98027378 -0.95822869  1.93915389]
# iteration =  469, loss = 7.12180, [-2.98054358 -0.95822865  1.93915387]
# iteration =  470, loss = 7.12179, [-2.98081068 -0.95822861  1.93915385]
# iteration =  471, loss = 7.12179, [-2.9810751  -0.95822858  1.93915383]
# iteration =  472, loss = 7.12178, [-2.98133689 -0.95822854  1.93915381]
# iteration =  473, loss = 7.12177, [-2.98159605 -0.9582285   1.93915379]
# iteration =  474, loss = 7.12177, [-2.98185263 -0.95822846  1.93915377]
# iteration =  475, loss = 7.12176, [-2.98210663 -0.95822843  1.93915375]
# iteration =  476, loss = 7.12175, [-2.9823581  -0.95822839  1.93915373]
# iteration =  477, loss = 7.12175, [-2.98260706 -0.95822835  1.93915371]
# iteration =  478, loss = 7.12174, [-2.98285352 -0.95822832  1.93915369]
# iteration =  479, loss = 7.12174, [-2.98309752 -0.95822828  1.93915367]
# iteration =  480, loss = 7.12173, [-2.98333908 -0.95822825  1.93915365]
# iteration =  481, loss = 7.12172, [-2.98357822 -0.95822821  1.93915364]
# iteration =  482, loss = 7.12172, [-2.98381497 -0.95822818  1.93915362]
# iteration =  483, loss = 7.12171, [-2.98404936 -0.95822814  1.9391536 ]
# iteration =  484, loss = 7.12171, [-2.9842814  -0.95822811  1.93915358]
# iteration =  485, loss = 7.12170, [-2.98451112 -0.95822808  1.93915357]
# iteration =  486, loss = 7.12170, [-2.98473854 -0.95822804  1.93915355]
# iteration =  487, loss = 7.12169, [-2.98496369 -0.95822801  1.93915353]
# iteration =  488, loss = 7.12169, [-2.98518659 -0.95822798  1.93915351]
# iteration =  489, loss = 7.12168, [-2.98540726 -0.95822795  1.9391535 ]
# iteration =  490, loss = 7.12168, [-2.98562572 -0.95822792  1.93915348]
# iteration =  491, loss = 7.12167, [-2.985842   -0.95822788  1.93915346]
# iteration =  492, loss = 7.12167, [-2.98605611 -0.95822785  1.93915345]
# iteration =  493, loss = 7.12166, [-2.98626809 -0.95822782  1.93915343]
# iteration =  494, loss = 7.12166, [-2.98647794 -0.95822779  1.93915342]
# iteration =  495, loss = 7.12166, [-2.98668569 -0.95822776  1.9391534 ]
# iteration =  496, loss = 7.12165, [-2.98689137 -0.95822773  1.93915338]
# iteration =  497, loss = 7.12165, [-2.98709499 -0.9582277   1.93915337]
# iteration =  498, loss = 7.12164, [-2.98729658 -0.95822767  1.93915335]
# iteration =  499, loss = 7.12164, [-2.98749615 -0.95822764  1.93915334]
# iteration =  500, loss = 7.12163, [-2.98769372 -0.95822762  1.93915332]
# iteration =  501, loss = 7.12163, [-2.98788932 -0.95822759  1.93915331]
# iteration =  502, loss = 7.12163, [-2.98808296 -0.95822756  1.93915329]
# iteration =  503, loss = 7.12162, [-2.98827466 -0.95822753  1.93915328]
# iteration =  504, loss = 7.12162, [-2.98846445 -0.9582275   1.93915327]
# iteration =  505, loss = 7.12162, [-2.98865234 -0.95822748  1.93915325]
# iteration =  506, loss = 7.12161, [-2.98883835 -0.95822745  1.93915324]
# iteration =  507, loss = 7.12161, [-2.9890225  -0.95822742  1.93915322]
# iteration =  508, loss = 7.12161, [-2.98920481 -0.9582274   1.93915321]
# iteration =  509, loss = 7.12160, [-2.9893853  -0.95822737  1.9391532 ]
# iteration =  510, loss = 7.12160, [-2.98956398 -0.95822735  1.93915318]
# iteration =  511, loss = 7.12160, [-2.98974087 -0.95822732  1.93915317]
# iteration =  512, loss = 7.12159, [-2.989916   -0.95822729  1.93915316]
# iteration =  513, loss = 7.12159, [-2.99008937 -0.95822727  1.93915314]
# iteration =  514, loss = 7.12159, [-2.99026102 -0.95822724  1.93915313]
# iteration =  515, loss = 7.12159, [-2.99043094 -0.95822722  1.93915312]
# iteration =  516, loss = 7.12158, [-2.99059917 -0.9582272   1.9391531 ]
# iteration =  517, loss = 7.12158, [-2.99076571 -0.95822717  1.93915309]
# iteration =  518, loss = 7.12158, [-2.99093059 -0.95822715  1.93915308]
# iteration =  519, loss = 7.12157, [-2.99109381 -0.95822712  1.93915307]
# iteration =  520, loss = 7.12157, [-2.99125541 -0.9582271   1.93915305]
# iteration =  521, loss = 7.12157, [-2.99141539 -0.95822708  1.93915304]
# iteration =  522, loss = 7.12157, [-2.99157377 -0.95822705  1.93915303]
# iteration =  523, loss = 7.12156, [-2.99173057 -0.95822703  1.93915302]
# iteration =  524, loss = 7.12156, [-2.9918858  -0.95822701  1.93915301]
# iteration =  525, loss = 7.12156, [-2.99203947 -0.95822699  1.93915299]
# iteration =  526, loss = 7.12156, [-2.99219161 -0.95822696  1.93915298]
# iteration =  527, loss = 7.12155, [-2.99234223 -0.95822694  1.93915297]
# iteration =  528, loss = 7.12155, [-2.99249134 -0.95822692  1.93915296]
# iteration =  529, loss = 7.12155, [-2.99263897 -0.9582269   1.93915295]
# iteration =  530, loss = 7.12155, [-2.99278511 -0.95822688  1.93915294]
# iteration =  531, loss = 7.12155, [-2.99292979 -0.95822686  1.93915293]
# iteration =  532, loss = 7.12154, [-2.99307303 -0.95822684  1.93915292]
# iteration =  533, loss = 7.12154, [-2.99321483 -0.95822682  1.93915291]
# iteration =  534, loss = 7.12154, [-2.99335522 -0.9582268   1.9391529 ]
# iteration =  535, loss = 7.12154, [-2.9934942  -0.95822678  1.93915288]
# iteration =  536, loss = 7.12154, [-2.9936318  -0.95822676  1.93915287]
# iteration =  537, loss = 7.12153, [-2.99376801 -0.95822674  1.93915286]
# iteration =  538, loss = 7.12153, [-2.99390287 -0.95822672  1.93915285]
# iteration =  539, loss = 7.12153, [-2.99403637 -0.9582267   1.93915284]
# iteration =  540, loss = 7.12153, [-2.99416854 -0.95822668  1.93915283]
# iteration =  541, loss = 7.12153, [-2.99429939 -0.95822666  1.93915282]
# iteration =  542, loss = 7.12153, [-2.99442893 -0.95822664  1.93915281]
# iteration =  543, loss = 7.12152, [-2.99455718 -0.95822662  1.9391528 ]
# iteration =  544, loss = 7.12152, [-2.99468414 -0.9582266   1.93915279]
# iteration =  545, loss = 7.12152, [-2.99480983 -0.95822658  1.93915278]
# iteration =  546, loss = 7.12152, [-2.99493427 -0.95822657  1.93915278]
# iteration =  547, loss = 7.12152, [-2.99505746 -0.95822655  1.93915277]
# iteration =  548, loss = 7.12152, [-2.99517942 -0.95822653  1.93915276]
# iteration =  549, loss = 7.12152, [-2.99530016 -0.95822651  1.93915275]
# iteration =  550, loss = 7.12151, [-2.9954197  -0.9582265   1.93915274]
# iteration =  551, loss = 7.12151, [-2.99553803 -0.95822648  1.93915273]
# iteration =  552, loss = 7.12151, [-2.99565519 -0.95822646  1.93915272]
# iteration =  553, loss = 7.12151, [-2.99577117 -0.95822645  1.93915271]
# iteration =  554, loss = 7.12151, [-2.99588599 -0.95822643  1.9391527 ]
# iteration =  555, loss = 7.12151, [-2.99599967 -0.95822641  1.93915269]
# iteration =  556, loss = 7.12151, [-2.99611221 -0.9582264   1.93915269]
# iteration =  557, loss = 7.12150, [-2.99622362 -0.95822638  1.93915268]
# iteration =  558, loss = 7.12150, [-2.99633392 -0.95822636  1.93915267]
# iteration =  559, loss = 7.12150, [-2.99644311 -0.95822635  1.93915266]
# iteration =  560, loss = 7.12150, [-2.99655122 -0.95822633  1.93915265]
# iteration =  561, loss = 7.12150, [-2.99665824 -0.95822632  1.93915264]
# iteration =  562, loss = 7.12150, [-2.99676419 -0.9582263   1.93915264]
# iteration =  563, loss = 7.12150, [-2.99686908 -0.95822629  1.93915263]
# iteration =  564, loss = 7.12150, [-2.99697293 -0.95822627  1.93915262]
# iteration =  565, loss = 7.12150, [-2.99707573 -0.95822626  1.93915261]
# iteration =  566, loss = 7.12149, [-2.99717751 -0.95822624  1.93915261]
# iteration =  567, loss = 7.12149, [-2.99727827 -0.95822623  1.9391526 ]
# iteration =  568, loss = 7.12149, [-2.99737802 -0.95822621  1.93915259]
# iteration =  569, loss = 7.12149, [-2.99747677 -0.9582262   1.93915258]
# iteration =  570, loss = 7.12149, [-2.99757454 -0.95822618  1.93915258]
# iteration =  571, loss = 7.12149, [-2.99767133 -0.95822617  1.93915257]
# iteration =  572, loss = 7.12149, [-2.99776715 -0.95822616  1.93915256]
# iteration =  573, loss = 7.12149, [-2.99786202 -0.95822614  1.93915255]
# iteration =  574, loss = 7.12149, [-2.99795593 -0.95822613  1.93915255]
# iteration =  575, loss = 7.12149, [-2.9980489  -0.95822612  1.93915254]
# iteration =  576, loss = 7.12149, [-2.99814095 -0.9582261   1.93915253]
# iteration =  577, loss = 7.12148, [-2.99823208 -0.95822609  1.93915253]
# iteration =  578, loss = 7.12148, [-2.99832229 -0.95822608  1.93915252]
# iteration =  579, loss = 7.12148, [-2.9984116  -0.95822606  1.93915251]
# iteration =  580, loss = 7.12148, [-2.99850002 -0.95822605  1.93915251]
# iteration =  581, loss = 7.12148, [-2.99858755 -0.95822604  1.9391525 ]
# iteration =  582, loss = 7.12148, [-2.99867421 -0.95822602  1.93915249]
# iteration =  583, loss = 7.12148, [-2.99876001 -0.95822601  1.93915249]
# iteration =  584, loss = 7.12148, [-2.99884494 -0.958226    1.93915248]
# iteration =  585, loss = 7.12148, [-2.99892903 -0.95822599  1.93915247]
# iteration =  586, loss = 7.12148, [-2.99901227 -0.95822598  1.93915247]
# iteration =  587, loss = 7.12148, [-2.99909468 -0.95822596  1.93915246]
# iteration =  588, loss = 7.12148, [-2.99917627 -0.95822595  1.93915245]
# iteration =  589, loss = 7.12148, [-2.99925704 -0.95822594  1.93915245]
# iteration =  590, loss = 7.12147, [-2.99933701 -0.95822593  1.93915244]
# iteration =  591, loss = 7.12147, [-2.99941617 -0.95822592  1.93915244]
# iteration =  592, loss = 7.12147, [-2.99949454 -0.95822591  1.93915243]
# iteration =  593, loss = 7.12147, [-2.99957213 -0.95822589  1.93915242]
# iteration =  594, loss = 7.12147, [-2.99964895 -0.95822588  1.93915242]
# iteration =  595, loss = 7.12147, [-2.99972499 -0.95822587  1.93915241]
# iteration =  596, loss = 7.12147, [-2.99980028 -0.95822586  1.93915241]
# iteration =  597, loss = 7.12147, [-2.99987481 -0.95822585  1.9391524 ]
# iteration =  598, loss = 7.12147, [-2.99994859 -0.95822584  1.9391524 ]
# iteration =  599, loss = 7.12147, [-3.00002164 -0.95822583  1.93915239]
# iteration =  600, loss = 7.12147, [-3.00009396 -0.95822582  1.93915238]
# iteration =  601, loss = 7.12147, [-3.00016556 -0.95822581  1.93915238]
# iteration =  602, loss = 7.12147, [-3.00023643 -0.9582258   1.93915237]
# iteration =  603, loss = 7.12147, [-3.0003066  -0.95822579  1.93915237]
# iteration =  604, loss = 7.12147, [-3.00037607 -0.95822578  1.93915236]
# iteration =  605, loss = 7.12147, [-3.00044485 -0.95822577  1.93915236]
# iteration =  606, loss = 7.12147, [-3.00051293 -0.95822576  1.93915235]
# iteration =  607, loss = 7.12147, [-3.00058034 -0.95822575  1.93915235]
# iteration =  608, loss = 7.12147, [-3.00064707 -0.95822574  1.93915234]
# iteration =  609, loss = 7.12147, [-3.00071313 -0.95822573  1.93915234]
# iteration =  610, loss = 7.12146, [-3.00077854 -0.95822572  1.93915233]
# iteration =  611, loss = 7.12146, [-3.00084329 -0.95822571  1.93915233]
# iteration =  612, loss = 7.12146, [-3.00090739 -0.9582257   1.93915232]
# iteration =  613, loss = 7.12146, [-3.00097085 -0.95822569  1.93915232]
# iteration =  614, loss = 7.12146, [-3.00103367 -0.95822568  1.93915231]
# iteration =  615, loss = 7.12146, [-3.00109587 -0.95822567  1.93915231]
# iteration =  616, loss = 7.12146, [-3.00115745 -0.95822566  1.9391523 ]
# iteration =  617, loss = 7.12146, [-3.00121841 -0.95822566  1.9391523 ]
# iteration =  618, loss = 7.12146, [-3.00127876 -0.95822565  1.93915229]
# iteration =  619, loss = 7.12146, [-3.00133851 -0.95822564  1.93915229]
# iteration =  620, loss = 7.12146, [-3.00139766 -0.95822563  1.93915229]
# iteration =  621, loss = 7.12146, [-3.00145621 -0.95822562  1.93915228]
# iteration =  622, loss = 7.12146, [-3.00151419 -0.95822561  1.93915228]
# iteration =  623, loss = 7.12146, [-3.00157158 -0.9582256   1.93915227]
# iteration =  624, loss = 7.12146, [-3.0016284  -0.9582256   1.93915227]
# iteration =  625, loss = 7.12146, [-3.00168465 -0.95822559  1.93915226]
# iteration =  626, loss = 7.12146, [-3.00174034 -0.95822558  1.93915226]
# iteration =  627, loss = 7.12146, [-3.00179547 -0.95822557  1.93915226]
# iteration =  628, loss = 7.12146, [-3.00185005 -0.95822556  1.93915225]
# iteration =  629, loss = 7.12146, [-3.00190408 -0.95822556  1.93915225]
# iteration =  630, loss = 7.12146, [-3.00195758 -0.95822555  1.93915224]
# iteration =  631, loss = 7.12146, [-3.00201053 -0.95822554  1.93915224]
# iteration =  632, loss = 7.12146, [-3.00206296 -0.95822553  1.93915224]
# iteration =  633, loss = 7.12146, [-3.00211487 -0.95822553  1.93915223]
# iteration =  634, loss = 7.12146, [-3.00216626 -0.95822552  1.93915223]
# iteration =  635, loss = 7.12146, [-3.00221713 -0.95822551  1.93915222]
# iteration =  636, loss = 7.12146, [-3.00226749 -0.9582255   1.93915222]
# iteration =  637, loss = 7.12146, [-3.00231735 -0.9582255   1.93915222]
# iteration =  638, loss = 7.12146, [-3.00236671 -0.95822549  1.93915221]
# iteration =  639, loss = 7.12146, [-3.00241558 -0.95822548  1.93915221]
# iteration =  640, loss = 7.12146, [-3.00246396 -0.95822547  1.9391522 ]
# iteration =  641, loss = 7.12145, [-3.00251185 -0.95822547  1.9391522 ]
# iteration =  642, loss = 7.12145, [-3.00255927 -0.95822546  1.9391522 ]
# iteration =  643, loss = 7.12145, [-3.00260621 -0.95822545  1.93915219]
# iteration =  644, loss = 7.12145, [-3.00265268 -0.95822545  1.93915219]
# iteration =  645, loss = 7.12145, [-3.00269869 -0.95822544  1.93915219]
# iteration =  646, loss = 7.12145, [-3.00274424 -0.95822543  1.93915218]
# iteration =  647, loss = 7.12145, [-3.00278933 -0.95822543  1.93915218]
# iteration =  648, loss = 7.12145, [-3.00283397 -0.95822542  1.93915218]
# iteration =  649, loss = 7.12145, [-3.00287817 -0.95822541  1.93915217]
# iteration =  650, loss = 7.12145, [-3.00292192 -0.95822541  1.93915217]
# iteration =  651, loss = 7.12145, [-3.00296524 -0.9582254   1.93915217]
# iteration =  652, loss = 7.12145, [-3.00300812 -0.9582254   1.93915216]
# iteration =  653, loss = 7.12145, [-3.00305057 -0.95822539  1.93915216]
# iteration =  654, loss = 7.12145, [-3.0030926  -0.95822538  1.93915216]
# iteration =  655, loss = 7.12145, [-3.00313421 -0.95822538  1.93915215]
# iteration =  656, loss = 7.12145, [-3.0031754  -0.95822537  1.93915215]
# iteration =  657, loss = 7.12145, [-3.00321618 -0.95822537  1.93915215]
# iteration =  658, loss = 7.12145, [-3.00325656 -0.95822536  1.93915214]
# iteration =  659, loss = 7.12145, [-3.00329652 -0.95822535  1.93915214]
# iteration =  660, loss = 7.12145, [-3.00333609 -0.95822535  1.93915214]
# iteration =  661, loss = 7.12145, [-3.00337527 -0.95822534  1.93915214]
# iteration =  662, loss = 7.12145, [-3.00341405 -0.95822534  1.93915213]
# iteration =  663, loss = 7.12145, [-3.00345244 -0.95822533  1.93915213]
# iteration =  664, loss = 7.12145, [-3.00349045 -0.95822533  1.93915213]
# iteration =  665, loss = 7.12145, [-3.00352808 -0.95822532  1.93915212]
# ...
# iteration =  778, loss = 7.12144, [-3.00605687 -0.95822495  1.93915193]
# iteration =  779, loss = 7.12144, [-3.00606884 -0.95822495  1.93915193]
# iteration =  780, loss = 7.12144, [-3.00608068 -0.95822495  1.93915193]
# iteration =  781, loss = 7.12144, [-3.00609241 -0.95822495  1.93915193]
# iteration =  782, loss = 7.12144, [-3.00610402 -0.95822495  1.93915193]
# iteration =  783, loss = 7.12144, [-3.00611551 -0.95822495  1.93915193]
# iteration =  784, loss = 7.12144, [-3.00612689 -0.95822494  1.93915193]
# iteration =  785, loss = 7.12144, [-3.00613816 -0.95822494  1.93915193]
# iteration =  786, loss = 7.12144, [-3.00614931 -0.95822494  1.93915193]
# iteration =  787, loss = 7.12144, [-3.00616035 -0.95822494  1.93915192]
# iteration =  788, loss = 7.12144, [-3.00617129 -0.95822494  1.93915192]
# iteration =  789, loss = 7.12144, [-3.00618211 -0.95822494  1.93915192]
# iteration =  790, loss = 7.12144, [-3.00619282 -0.95822493  1.93915192]
# iteration =  791, loss = 7.12144, [-3.00620343 -0.95822493  1.93915192]
# iteration =  792, loss = 7.12144, [-3.00621393 -0.95822493  1.93915192]
# iteration =  793, loss = 7.12144, [-3.00622432 -0.95822493  1.93915192]
# iteration =  794, loss = 7.12144, [-3.00623461 -0.95822493  1.93915192]
# iteration =  795, loss = 7.12144, [-3.0062448  -0.95822493  1.93915192]
# iteration =  796, loss = 7.12144, [-3.00625489 -0.95822493  1.93915192]
# iteration =  797, loss = 7.12144, [-3.00626488 -0.95822492  1.93915192]
# iteration =  798, loss = 7.12144, [-3.00627476 -0.95822492  1.93915192]
# iteration =  799, loss = 7.12144, [-3.00628455 -0.95822492  1.93915192]
# iteration =  800, loss = 7.12144, [-3.00629424 -0.95822492  1.93915191]
# iteration =  801, loss = 7.12144, [-3.00630383 -0.95822492  1.93915191]
# iteration =  802, loss = 7.12144, [-3.00631333 -0.95822492  1.93915191]
# iteration =  803, loss = 7.12144, [-3.00632273 -0.95822492  1.93915191]
# iteration =  804, loss = 7.12144, [-3.00633204 -0.95822491  1.93915191]
# iteration =  805, loss = 7.12144, [-3.00634125 -0.95822491  1.93915191]
# iteration =  806, loss = 7.12144, [-3.00635037 -0.95822491  1.93915191]
# iteration =  807, loss = 7.12144, [-3.0063594  -0.95822491  1.93915191]
# iteration =  808, loss = 7.12144, [-3.00636834 -0.95822491  1.93915191]
# iteration =  809, loss = 7.12144, [-3.00637719 -0.95822491  1.93915191]
# iteration =  810, loss = 7.12144, [-3.00638596 -0.95822491  1.93915191]
# iteration =  811, loss = 7.12144, [-3.00639463 -0.95822491  1.93915191]
# iteration =  812, loss = 7.12144, [-3.00640322 -0.9582249   1.93915191]
# iteration =  813, loss = 7.12144, [-3.00641172 -0.9582249   1.93915191]
# iteration =  814, loss = 7.12144, [-3.00642014 -0.9582249   1.93915191]
# iteration =  815, loss = 7.12144, [-3.00642847 -0.9582249   1.9391519 ]
# iteration =  816, loss = 7.12144, [-3.00643672 -0.9582249   1.9391519 ]
# iteration =  817, loss = 7.12144, [-3.00644489 -0.9582249   1.9391519 ]
# iteration =  818, loss = 7.12144, [-3.00645298 -0.9582249   1.9391519 ]
# iteration =  819, loss = 7.12144, [-3.00646098 -0.9582249   1.9391519 ]
# iteration =  820, loss = 7.12144, [-3.00646891 -0.95822489  1.9391519 ]
# iteration =  821, loss = 7.12144, [-3.00647675 -0.95822489  1.9391519 ]
# iteration =  822, loss = 7.12144, [-3.00648452 -0.95822489  1.9391519 ]
# iteration =  823, loss = 7.12144, [-3.00649221 -0.95822489  1.9391519 ]
# iteration =  824, loss = 7.12144, [-3.00649982 -0.95822489  1.9391519 ]
# iteration =  825, loss = 7.12144, [-3.00650736 -0.95822489  1.9391519 ]
# iteration =  826, loss = 7.12144, [-3.00651482 -0.95822489  1.9391519 ]
# iteration =  827, loss = 7.12144, [-3.00652221 -0.95822489  1.9391519 ]
# iteration =  828, loss = 7.12144, [-3.00652952 -0.95822489  1.9391519 ]
# iteration =  829, loss = 7.12144, [-3.00653676 -0.95822488  1.9391519 ]
# iteration =  830, loss = 7.12144, [-3.00654392 -0.95822488  1.9391519 ]
# iteration =  831, loss = 7.12144, [-3.00655102 -0.95822488  1.9391519 ]
# iteration =  832, loss = 7.12144, [-3.00655804 -0.95822488  1.93915189]
# iteration =  833, loss = 7.12144, [-3.006565   -0.95822488  1.93915189]
# iteration =  834, loss = 7.12144, [-3.00657188 -0.95822488  1.93915189]
# iteration =  835, loss = 7.12144, [-3.0065787  -0.95822488  1.93915189]
# iteration =  836, loss = 7.12144, [-3.00658545 -0.95822488  1.93915189]
# iteration =  837, loss = 7.12144, [-3.00659213 -0.95822488  1.93915189]
# iteration =  838, loss = 7.12144, [-3.00659874 -0.95822488  1.93915189]
# iteration =  839, loss = 7.12144, [-3.00660529 -0.95822487  1.93915189]
# iteration =  840, loss = 7.12144, [-3.00661177 -0.95822487  1.93915189]
# iteration =  841, loss = 7.12144, [-3.00661819 -0.95822487  1.93915189]
# iteration =  842, loss = 7.12144, [-3.00662454 -0.95822487  1.93915189]
# iteration =  843, loss = 7.12144, [-3.00663083 -0.95822487  1.93915189]
# iteration =  844, loss = 7.12144, [-3.00663706 -0.95822487  1.93915189]
# iteration =  845, loss = 7.12144, [-3.00664322 -0.95822487  1.93915189]
# iteration =  846, loss = 7.12144, [-3.00664932 -0.95822487  1.93915189]
# iteration =  847, loss = 7.12144, [-3.00665536 -0.95822487  1.93915189]
# iteration =  848, loss = 7.12144, [-3.00666134 -0.95822487  1.93915189]
# iteration =  849, loss = 7.12144, [-3.00666727 -0.95822487  1.93915189]
# iteration =  850, loss = 7.12144, [-3.00667313 -0.95822486  1.93915189]
# iteration =  851, loss = 7.12144, [-3.00667893 -0.95822486  1.93915189]
# iteration =  852, loss = 7.12144, [-3.00668468 -0.95822486  1.93915189]
# iteration =  853, loss = 7.12144, [-3.00669036 -0.95822486  1.93915188]
# iteration =  854, loss = 7.12144, [-3.006696   -0.95822486  1.93915188]
# iteration =  855, loss = 7.12144, [-3.00670157 -0.95822486  1.93915188]
# iteration =  856, loss = 7.12144, [-3.00670709 -0.95822486  1.93915188]
# iteration =  857, loss = 7.12144, [-3.00671255 -0.95822486  1.93915188]
# iteration =  858, loss = 7.12144, [-3.00671796 -0.95822486  1.93915188]
# iteration =  859, loss = 7.12144, [-3.00672332 -0.95822486  1.93915188]
# iteration =  860, loss = 7.12144, [-3.00672862 -0.95822486  1.93915188]
# iteration =  861, loss = 7.12144, [-3.00673387 -0.95822486  1.93915188]
# iteration =  862, loss = 7.12144, [-3.00673906 -0.95822486  1.93915188]
# iteration =  863, loss = 7.12144, [-3.00674421 -0.95822485  1.93915188]
# iteration =  864, loss = 7.12144, [-3.0067493  -0.95822485  1.93915188]
# iteration =  865, loss = 7.12144, [-3.00675434 -0.95822485  1.93915188]
# iteration =  866, loss = 7.12144, [-3.00675933 -0.95822485  1.93915188]
# iteration =  867, loss = 7.12144, [-3.00676427 -0.95822485  1.93915188]
# iteration =  868, loss = 7.12144, [-3.00676917 -0.95822485  1.93915188]
# iteration =  869, loss = 7.12144, [-3.00677401 -0.95822485  1.93915188]
# iteration =  870, loss = 7.12144, [-3.0067788  -0.95822485  1.93915188]
# iteration =  871, loss = 7.12144, [-3.00678355 -0.95822485  1.93915188]
# iteration =  872, loss = 7.12144, [-3.00678825 -0.95822485  1.93915188]
# iteration =  873, loss = 7.12144, [-3.0067929  -0.95822485  1.93915188]
# iteration =  874, loss = 7.12144, [-3.00679751 -0.95822485  1.93915188]
# iteration =  875, loss = 7.12144, [-3.00680207 -0.95822485  1.93915188]
# iteration =  876, loss = 7.12144, [-3.00680658 -0.95822485  1.93915188]
# iteration =  877, loss = 7.12144, [-3.00681105 -0.95822484  1.93915188]
# iteration =  878, loss = 7.12144, [-3.00681547 -0.95822484  1.93915188]
# iteration =  879, loss = 7.12144, [-3.00681985 -0.95822484  1.93915187]
# iteration =  880, loss = 7.12144, [-3.00682419 -0.95822484  1.93915187]
# iteration =  881, loss = 7.12144, [-3.00682848 -0.95822484  1.93915187]
# iteration =  882, loss = 7.12144, [-3.00683273 -0.95822484  1.93915187]
# iteration =  883, loss = 7.12144, [-3.00683694 -0.95822484  1.93915187]
# iteration =  884, loss = 7.12144, [-3.00684111 -0.95822484  1.93915187]
# iteration =  885, loss = 7.12144, [-3.00684523 -0.95822484  1.93915187]
# iteration =  886, loss = 7.12144, [-3.00684931 -0.95822484  1.93915187]
# iteration =  887, loss = 7.12144, [-3.00685335 -0.95822484  1.93915187]
# iteration =  888, loss = 7.12144, [-3.00685735 -0.95822484  1.93915187]
# iteration =  889, loss = 7.12144, [-3.00686131 -0.95822484  1.93915187]
# iteration =  890, loss = 7.12144, [-3.00686524 -0.95822484  1.93915187]
# iteration =  891, loss = 7.12144, [-3.00686912 -0.95822484  1.93915187]
# iteration =  892, loss = 7.12144, [-3.00687296 -0.95822484  1.93915187]
# iteration =  893, loss = 7.12144, [-3.00687677 -0.95822484  1.93915187]
# iteration =  894, loss = 7.12144, [-3.00688053 -0.95822483  1.93915187]
# iteration =  895, loss = 7.12144, [-3.00688426 -0.95822483  1.93915187]
# iteration =  896, loss = 7.12144, [-3.00688796 -0.95822483  1.93915187]
# iteration =  897, loss = 7.12144, [-3.00689161 -0.95822483  1.93915187]
# iteration =  898, loss = 7.12144, [-3.00689523 -0.95822483  1.93915187]
# iteration =  899, loss = 7.12144, [-3.00689881 -0.95822483  1.93915187]
# iteration =  900, loss = 7.12144, [-3.00690236 -0.95822483  1.93915187]
# iteration =  901, loss = 7.12144, [-3.00690587 -0.95822483  1.93915187]
# iteration =  902, loss = 7.12144, [-3.00690935 -0.95822483  1.93915187]
# iteration =  903, loss = 7.12144, [-3.00691279 -0.95822483  1.93915187]
# iteration =  904, loss = 7.12144, [-3.00691619 -0.95822483  1.93915187]
# iteration =  905, loss = 7.12144, [-3.00691957 -0.95822483  1.93915187]
# iteration =  906, loss = 7.12144, [-3.00692291 -0.95822483  1.93915187]
# iteration =  907, loss = 7.12144, [-3.00692621 -0.95822483  1.93915187]
# iteration =  908, loss = 7.12144, [-3.00692948 -0.95822483  1.93915187]
# iteration =  909, loss = 7.12144, [-3.00693272 -0.95822483  1.93915187]
# iteration =  910, loss = 7.12144, [-3.00693593 -0.95822483  1.93915187]
# iteration =  911, loss = 7.12144, [-3.00693911 -0.95822483  1.93915187]
# iteration =  912, loss = 7.12144, [-3.00694225 -0.95822483  1.93915187]
# iteration =  913, loss = 7.12144, [-3.00694536 -0.95822483  1.93915187]
# iteration =  914, loss = 7.12144, [-3.00694844 -0.95822482  1.93915187]
# iteration =  915, loss = 7.12144, [-3.00695149 -0.95822482  1.93915186]
# iteration =  916, loss = 7.12144, [-3.00695451 -0.95822482  1.93915186]
# iteration =  917, loss = 7.12144, [-3.0069575  -0.95822482  1.93915186]
# iteration =  918, loss = 7.12144, [-3.00696046 -0.95822482  1.93915186]
# iteration =  919, loss = 7.12144, [-3.00696339 -0.95822482  1.93915186]
# iteration =  920, loss = 7.12144, [-3.00696629 -0.95822482  1.93915186]
# iteration =  921, loss = 7.12144, [-3.00696916 -0.95822482  1.93915186]
# iteration =  922, loss = 7.12144, [-3.00697201 -0.95822482  1.93915186]
# iteration =  923, loss = 7.12144, [-3.00697482 -0.95822482  1.93915186]
# iteration =  924, loss = 7.12144, [-3.00697761 -0.95822482  1.93915186]
# iteration =  925, loss = 7.12144, [-3.00698037 -0.95822482  1.93915186]
# iteration =  926, loss = 7.12144, [-3.0069831  -0.95822482  1.93915186]
# iteration =  927, loss = 7.12144, [-3.0069858  -0.95822482  1.93915186]
# iteration =  928, loss = 7.12144, [-3.00698848 -0.95822482  1.93915186]
# iteration =  929, loss = 7.12144, [-3.00699113 -0.95822482  1.93915186]
# iteration =  930, loss = 7.12144, [-3.00699375 -0.95822482  1.93915186]
# iteration =  931, loss = 7.12144, [-3.00699635 -0.95822482  1.93915186]
# iteration =  932, loss = 7.12144, [-3.00699892 -0.95822482  1.93915186]
# iteration =  933, loss = 7.12144, [-3.00700147 -0.95822482  1.93915186]
# iteration =  934, loss = 7.12144, [-3.00700399 -0.95822482  1.93915186]
# iteration =  935, loss = 7.12144, [-3.00700648 -0.95822482  1.93915186]
# iteration =  936, loss = 7.12144, [-3.00700895 -0.95822482  1.93915186]
# iteration =  937, loss = 7.12144, [-3.0070114  -0.95822482  1.93915186]
# iteration =  938, loss = 7.12144, [-3.00701382 -0.95822482  1.93915186]
# iteration =  939, loss = 7.12144, [-3.00701621 -0.95822482  1.93915186]
# iteration =  940, loss = 7.12144, [-3.00701859 -0.95822481  1.93915186]
# iteration =  941, loss = 7.12144, [-3.00702093 -0.95822481  1.93915186]
# iteration =  942, loss = 7.12144, [-3.00702326 -0.95822481  1.93915186]
# iteration =  943, loss = 7.12144, [-3.00702556 -0.95822481  1.93915186]
# iteration =  944, loss = 7.12144, [-3.00702784 -0.95822481  1.93915186]
# iteration =  945, loss = 7.12144, [-3.0070301  -0.95822481  1.93915186]
# iteration =  946, loss = 7.12144, [-3.00703233 -0.95822481  1.93915186]
# iteration =  947, loss = 7.12144, [-3.00703454 -0.95822481  1.93915186]
# iteration =  948, loss = 7.12144, [-3.00703673 -0.95822481  1.93915186]
# iteration =  949, loss = 7.12144, [-3.0070389  -0.95822481  1.93915186]
# iteration =  950, loss = 7.12144, [-3.00704104 -0.95822481  1.93915186]
# iteration =  951, loss = 7.12144, [-3.00704317 -0.95822481  1.93915186]
# iteration =  952, loss = 7.12144, [-3.00704527 -0.95822481  1.93915186]
# iteration =  953, loss = 7.12144, [-3.00704735 -0.95822481  1.93915186]
# iteration =  954, loss = 7.12144, [-3.00704941 -0.95822481  1.93915186]
# iteration =  955, loss = 7.12144, [-3.00705146 -0.95822481  1.93915186]
# iteration =  956, loss = 7.12144, [-3.00705348 -0.95822481  1.93915186]
# iteration =  957, loss = 7.12144, [-3.00705548 -0.95822481  1.93915186]
# iteration =  958, loss = 7.12144, [-3.00705746 -0.95822481  1.93915186]
# iteration =  959, loss = 7.12144, [-3.00705942 -0.95822481  1.93915186]
# iteration =  960, loss = 7.12144, [-3.00706136 -0.95822481  1.93915186]
# iteration =  961, loss = 7.12144, [-3.00706328 -0.95822481  1.93915186]
# iteration =  962, loss = 7.12144, [-3.00706518 -0.95822481  1.93915186]
# iteration =  963, loss = 7.12144, [-3.00706706 -0.95822481  1.93915186]
# iteration =  964, loss = 7.12144, [-3.00706893 -0.95822481  1.93915186]
# iteration =  965, loss = 7.12144, [-3.00707077 -0.95822481  1.93915186]
# iteration =  966, loss = 7.12144, [-3.0070726  -0.95822481  1.93915186]
# iteration =  967, loss = 7.12144, [-3.00707441 -0.95822481  1.93915186]
# iteration =  968, loss = 7.12144, [-3.0070762  -0.95822481  1.93915186]
# iteration =  969, loss = 7.12144, [-3.00707797 -0.95822481  1.93915186]
# iteration =  970, loss = 7.12144, [-3.00707973 -0.95822481  1.93915186]
# iteration =  971, loss = 7.12144, [-3.00708146 -0.95822481  1.93915185]
# iteration =  972, loss = 7.12144, [-3.00708318 -0.95822481  1.93915185]
# iteration =  973, loss = 7.12144, [-3.00708489 -0.95822481  1.93915185]
# iteration =  974, loss = 7.12144, [-3.00708657 -0.9582248   1.93915185]
# iteration =  975, loss = 7.12144, [-3.00708824 -0.9582248   1.93915185]
# iteration =  976, loss = 7.12144, [-3.00708989 -0.9582248   1.93915185]
# iteration =  977, loss = 7.12144, [-3.00709153 -0.9582248   1.93915185]
# iteration =  978, loss = 7.12144, [-3.00709315 -0.9582248   1.93915185]
# iteration =  979, loss = 7.12144, [-3.00709475 -0.9582248   1.93915185]
# iteration =  980, loss = 7.12144, [-3.00709634 -0.9582248   1.93915185]
# iteration =  981, loss = 7.12144, [-3.00709791 -0.9582248   1.93915185]
# iteration =  982, loss = 7.12144, [-3.00709946 -0.9582248   1.93915185]
# iteration =  983, loss = 7.12144, [-3.00710101 -0.9582248   1.93915185]
# iteration =  984, loss = 7.12144, [-3.00710253 -0.9582248   1.93915185]
# iteration =  985, loss = 7.12144, [-3.00710404 -0.9582248   1.93915185]
# iteration =  986, loss = 7.12144, [-3.00710553 -0.9582248   1.93915185]
# iteration =  987, loss = 7.12144, [-3.00710701 -0.9582248   1.93915185]
# iteration =  988, loss = 7.12144, [-3.00710848 -0.9582248   1.93915185]
# iteration =  989, loss = 7.12144, [-3.00710993 -0.9582248   1.93915185]
# iteration =  990, loss = 7.12144, [-3.00711136 -0.9582248   1.93915185]
# iteration =  991, loss = 7.12144, [-3.00711278 -0.9582248   1.93915185]
# iteration =  992, loss = 7.12144, [-3.00711419 -0.9582248   1.93915185]
# iteration =  993, loss = 7.12144, [-3.00711558 -0.9582248   1.93915185]
# iteration =  994, loss = 7.12144, [-3.00711696 -0.9582248   1.93915185]
# iteration =  995, loss = 7.12144, [-3.00711833 -0.9582248   1.93915185]
# iteration =  996, loss = 7.12144, [-3.00711968 -0.9582248   1.93915185]
# iteration =  997, loss = 7.12144, [-3.00712102 -0.9582248   1.93915185]
# iteration =  998, loss = 7.12144, [-3.00712234 -0.9582248   1.93915185]
# iteration =  999, loss = 7.12144, [-3.00712365 -0.9582248   1.93915185]

# %%
f = theta[0] + theta[1] * xx + theta[2] * yy

# %% [markdown]
# ## plot the results

# %%
def plot_loss_curve(loss_iteration):

    plt.figure(figsize=(8,6))
    plt.title('loss')
    # ===== FILL UP THE CODE =====

    plt.plot(np.arange(1,1001), loss_iteration,'-', color = 'red')
    # ============================
    plt.tight_layout()
    plt.show()

# %%
def plot_data(xx, yy, zz):
    
    fig = plt.figure(figsize=(12, 8))
    ax  = plt.subplot(111, projection='3d')
    plt.title('data')
    # ===== FILL UP THE CODE =====

    ax.set_xlabel('$x$')
    ax.set_ylabel('$y$')
    ax.set_zlabel('$z$')

    ax.scatter(xx, yy, zz, marker='o', color='blue', alpha=0.2)
    # ============================    
    plt.tight_layout()
    plt.show()

# %%
def plot_model_parameter(theta_iteration):

    plt.figure(figsize=(8,6))
    plt.title('model parameter')
    # ===== FILL UP THE CODE =====
    plt.plot(np.arange(1,1001), theta_iteration[:,0],'-', color = 'red')
    plt.plot(np.arange(1,1001), theta_iteration[:,1],'-', color = 'green')
    plt.plot(np.arange(1,1001), theta_iteration[:,2],'-', color = 'blue')
    

    # ============================
    plt.tight_layout()
    plt.show()

# %%
plot_loss_curve(loss_iteration)

# %%
plot_model_parameter(theta_iteration)

# %%
# ===== FILL UP THE CODE =====
XX = np.arange(-10,10,0.01)
YY = np.arange(-10,10,0.01)

#XX = sorted(xx)
#YY = sorted(yy)
XX, YY = np.meshgrid(XX, YY)
ZZ = (XX * theta[1] + YY * theta[2]) + theta[0]

# ============================

def plot_surface(XX, YY, ZZ, xx, yy, zz):
    
    fig = plt.figure(figsize=(8,8))
    ax  = fig.add_subplot(111, projection='3d')
    plt.title('regression surface')
    
    
    ax  = plt.axes(projection='3d')
    # ===== FILL UP THE CODE =====
    
    ax.plot_surface(XX, YY, ZZ, cmap='plasma' )
    ax.scatter(xx, yy, zz, marker='o', color='green', alpha = 0.3)
    
   

    # ============================
    plt.tight_layout()
    plt.show()

# %%
plot_surface(XX, YY, ZZ, xx, yy, zz)

# %% [markdown]
# # * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *

# %% [markdown]
# # * results

# %% [markdown]
# # * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * *

# %% [markdown]
# ### # 01. plot the input data in blue point in 3-dimensional space

# %%
plot_data(xx, yy, zz)

# %% [markdown]
# ### # 02. plot the values of the model parameters $\theta_0$ in red curve, $\theta_1$ in green curve, and $\theta_2$ in blue curve over the gradient descent iterations

# %%
plot_model_parameter(theta_iteration)

# %% [markdown]
# ### # 03. plot the loss values $\mathcal{L}(\theta)$ in red curve over the gradient descent iterations

# %%
plot_loss_curve(loss_iteration)

# %% [markdown]
# ### # 04. plot the optimal regression surface $\hat{f}(\theta^*)$ in 3-dimensional space with a given set of data points superimposed

# %%
plot_surface(XX, YY, ZZ, xx, yy, zz)
